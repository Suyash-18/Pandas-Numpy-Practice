# %% [markdown]
# ## Data Updation and Delete/Drop too

# %%
import pandas as pd

# %%
df = pd.read_csv('players_20.csv')

# %%
df = df.set_index('short_name')

# %%
df
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
# J. Oblak              200389
# E. Hazard             183277
# ...                      ...
# Shao Shuai            245006
# Xiao Mingjie          250995
# Zhang Wei             252332
# Wang Haijian          251110
# Pan Ximing            233449
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# ...                                                              ...
# Shao Shuai         https://sofifa.com/player/245006/shuai-shao/20...
# ...

# %%
df=df.iloc[:,2:9]

# %%
# Updated the specific location/field 
df.loc['L. Messi', 'height_cm'] = 173
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %%
# Updated the all location/field 
df.loc[:, 'height_cm'] = 173
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %%
df.iloc[-1,:]
# Out:
# long_name                         潘喜明
# age                                26
# dob                        1993-01-11
# height_cm                         173
# weight_kg                          78
# nationality                  China PR
# club           Hebei China Fortune FC
# Name: Pan Ximing, dtype: object

# %%
import numpy as np
df.iloc[-1,:]=np.nan
df
# Out:
#                                              long_name   age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior  27.0  1992-02-05
# J. Oblak                                     Jan Oblak  26.0  1993-01-07
# E. Hazard                                  Eden Hazard  28.0  1991-01-07
# ...                                                ...   ...         ...
# Shao Shuai                                          邵帅  22.0  1997-03-10
# Xiao Mingjie                              Mingjie Xiao  22.0  1997-01-01
# Zhang Wei                                           张威  19.0  2000-05-16
# Wang Haijian                                       汪海健  18.0  2000-08-02
# Pan Ximing                                         NaN   NaN         NaN
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %%
df.drop('L. Messi', axis=0, inplace=True)
df
# Out:
#                                              long_name   age         dob  \
# short_name
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior  27.0  1992-02-05
# J. Oblak                                     Jan Oblak  26.0  1993-01-07
# E. Hazard                                  Eden Hazard  28.0  1991-01-07
# K. De Bruyne                           Kevin De Bruyne  28.0  1991-06-28
# ...                                                ...   ...         ...
# Shao Shuai                                          邵帅  22.0  1997-03-10
# Xiao Mingjie                              Mingjie Xiao  22.0  1997-01-01
# Zhang Wei                                           张威  19.0  2000-05-16
# Wang Haijian                                       汪海健  18.0  2000-08-02
# Pan Ximing                                         NaN   NaN         NaN
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %%
df.drop(index='Pan Ximing', inplace=True)
df
# Out:
#                                              long_name   age         dob  \
# short_name
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior  27.0  1992-02-05
# J. Oblak                                     Jan Oblak  26.0  1993-01-07
# E. Hazard                                  Eden Hazard  28.0  1991-01-07
# K. De Bruyne                           Kevin De Bruyne  28.0  1991-06-28
# ...                                                ...   ...         ...
# P. Martin                                  Paul Martin  20.0  1999-01-05
# Shao Shuai                                          邵帅  22.0  1997-03-10
# Xiao Mingjie                              Mingjie Xiao  22.0  1997-01-01
# Zhang Wei                                           张威  19.0  2000-05-16
# Wang Haijian                                       汪海健  18.0  2000-08-02
#
#                    height_cm  weight_kg          nationality  \
# short_name
# ...

# %%
df.drop('long_name', axis=1)
# Out:
#                     age         dob  height_cm  weight_kg  \
# short_name
# Cristiano Ronaldo  34.0  1985-02-05      173.0       83.0
# Neymar Jr          27.0  1992-02-05      173.0       68.0
# J. Oblak           26.0  1993-01-07      173.0       87.0
# E. Hazard          28.0  1991-01-07      173.0       74.0
# K. De Bruyne       28.0  1991-06-28      173.0       70.0
# ...                 ...         ...        ...        ...
# P. Martin          20.0  1999-01-05      173.0       84.0
# Shao Shuai         22.0  1997-03-10      173.0       79.0
# Xiao Mingjie       22.0  1997-01-01      173.0       66.0
# Zhang Wei          19.0  2000-05-16      173.0       75.0
# Wang Haijian       18.0  2000-08-02      173.0       74.0
#
#                            nationality                           club
# short_name
# Cristiano Ronaldo             Portugal                       Juventus
# Neymar Jr                       Brazil            Paris Saint-Germain
# ...

# %%
df.drop(columns=['long_name','age'])
# Out:
#                           dob  height_cm  weight_kg          nationality  \
# short_name
# Cristiano Ronaldo  1985-02-05      173.0       83.0             Portugal
# Neymar Jr          1992-02-05      173.0       68.0               Brazil
# J. Oblak           1993-01-07      173.0       87.0             Slovenia
# E. Hazard          1991-01-07      173.0       74.0              Belgium
# K. De Bruyne       1991-06-28      173.0       70.0              Belgium
# ...                       ...        ...        ...                  ...
# P. Martin          1999-01-05      173.0       84.0  Republic of Ireland
# Shao Shuai         1997-03-10      173.0       79.0             China PR
# Xiao Mingjie       1997-01-01      173.0       66.0             China PR
# Zhang Wei          2000-05-16      173.0       75.0             China PR
# Wang Haijian       2000-08-02      173.0       74.0             China PR
#
#                                             club
# short_name
# ...
