# %%
print("Hellow")
# Out:
# Hellow

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\suuas'

# %%
os.listdir()
# Out:
# ['-1.14-windows.xml',
#  '.AndroidStudio3.4',
#  '.arduinoIDE',
#  '.bashrc',
#  '.bash_history',
#  '.bash_profile',
#  '.cache',
#  '.config',
#  '.console-ninja',
#  '.copilot',
#  '.docker',
#  '.eclipse',
#  '.gitconfig',
#  '.gradle',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jdks',
#  '.jupyter',
#  '.lesshst',
#  '.librarymanager',
#  '.m2',
#  '.matplotlib',
#  '.ms-ad',
#  '.node_repl_history',
#  '.nvm',
#  '.ollama',
#  '.p2',
#  '.python_history',
#  '.redhat',
#  '.sao',
#  '.ssh',
#  '.streamlit',
#  '.templateengine',
#  '.thumbnails',
#  '.VirtualBox',
#  '.vscode',
#  '.vscode-shared',
#  'AndroidStudioProjects',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'CrossDevice',
#  'Documents',
#  'eclipse',
#  'eclipse-workspace',
#  'Favorites',
#  'HELLOWORLS.C',
#  'Links',
#  'Local Settings',
#  'My Documents',
#  'My project',
#  'My project (1)',
#  'MyApp',
#  'myenv',
#  'NetHood',
#  'New folder',
#  'npm-cache',
#  'NTUSER.DAT',
# ...

# %%
import pandas as pd

# %%
a = [[1,2],[3,4],[5,6]]
print(a)
# Out:
# [[1, 2], [3, 4], [5, 6]]

# %%
df = pd.DataFrame(a, index=["row1", "row2", "row3"], columns=['col1', 'col2'])
print(df)
# Out:
#       col1  col2
# row1     1     2
# row2     3     4
# row3     5     6

# %%
state = ['MP', 'MH', 'KA']
city = [4, 14, 9]

# %%
dict_city = {'States': state, 'Cities': city}

# %%
df_city = pd.DataFrame(dict_city)

# %%
df_city
# Out:
#   States  Cities
# 0     MP       4
# 1     MH      14
# 2     KA       9

# %%
df_exams = pd.read_csv('StudentsPerformance.csv')

# %%
#Methords Commonly used
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exams.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df_exams.head(11)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
#
#    test preparation course  math score  reading score  writing score
# 0                     none          72             72             74
# ...

# %%
df_exams.tail(11)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 989  female        group D                some college  free/reduced
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#Attributes Commonly used
df_exams.shape
# Out:
# (1000, 8)

# %%
df_exams.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
#Functions Commonly used
len(df_exams)
# Out:
# 1000

# %%
max(df_exams.index)
# Out:
# 999

# %%
min(df_exams.index)
# Out:
# 0

# %%
type(df_exams)
# Out:
# pandas.core.frame.DataFrame

# %%
round(df_exams, 2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#Selecting Columns
df_exams['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
type(df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
df_exams['gender'].index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_exams['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
df_exams.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
df_exams['math score']
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %%
#Selecting Multiple Columns
df_exams[['gender', 'math score', 'lunch']]
# Out:
#      gender  math score         lunch
# 0    female          72      standard
# 1    female          69      standard
# 2    female          90      standard
# 3      male          47  free/reduced
# 4      male          76      standard
# ..      ...         ...           ...
# 995  female          88      standard
# 996    male          62  free/reduced
# 997  female          59  free/reduced
# 998  female          68      standard
# 999  female          77  free/reduced
#
# [1000 rows x 3 columns]

# %%
type(df_exams[['gender', 'math score', 'lunch']])
# Out:
# pandas.core.frame.DataFrame

# %%
#Adding New Column to Dataframe
df_exams['total score'] = round((df_exams['math score'] + df_exams['reading score'] + df_exams['writing score'])/3, 2)

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
import numpy as np

# %%
#Creating an array of range 1000 here 0 will be included and 1000 won't
language_score = np.arange(0,1000)

# %%
#Length of array created using np
len(language_score)
# Out:
# 1000

# %%
#Here 1 is min number less than 100 is max and 1000 is the size of array needed
english_score = np.random.randint(1,100, size=1000)

# %%
df_exams['english score'] = english_score

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df_exams['total score'] = round((df_exams['math score'] + df_exams['reading score'] + df_exams['writing score'] + df_exams['english score'])/4, 2)

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#using assign() to add multiple columns
score1 = np.random.randint(1, 100, size=1000)
score2 = np.random.randint(1, 100, size=1000)

# %%
series1 = pd.Series(score1, index=np.arange(0, 1000))
series2 = pd.Series(score1, index=np.arange(0, 1000))

# %%
#This is only a copy orignal Dataframe is not changed
df_exams.assign(score1=series1, score2=series2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#Dataframe reflects changes when we assign using = operator
df_exams = df_exams.assign(score1=series1, score2=series2)

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#Adding new column using insert() this adds into orignal Dataframe here 1 is index in columns test is name and series1 is values
df_exams.insert(1, 'test', series1)

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    73        group B           bachelor's degree      standard
# 1    female    57        group C                some college      standard
# 2    female    47        group B             master's degree      standard
# 3      male    34        group A          associate's degree  free/reduced
# 4      male    68        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    51        group E             master's degree      standard
# 996    male    42        group C                 high school  free/reduced
# 997  female    55        group C                 high school  free/reduced
# 998  female    93        group D                some college      standard
# 999  female    19        group D                some college  free/reduced
#
# ...

# %%
#Calculate total sum, count, mean, std, min, max these are operations done on columns
df_exams['math score'].sum()
# Out:
# np.int64(66089)

# %%
df_exams['math score'].count()
# Out:
# np.int64(1000)

# %%
df_exams['math score'].mean()
# Out:
# np.float64(66.089)

# %%
df_exams['math score'].std()
# Out:
# np.float64(15.16308009600945)

# %%
df_exams['math score'].min()
# Out:
# np.int64(0)

# %%
df_exams['math score'].max()
# Out:
# np.int64(100)

# %%
df_exams.describe()
# Out:
#               test  math score  reading score  writing score  total score  \
# count  1000.000000  1000.00000    1000.000000    1000.000000  1000.000000
# mean     50.667000    66.08900      69.169000      68.054000    63.488750
# std      28.232059    15.16308      14.600192      15.195657    13.219652
# min       1.000000     0.00000      17.000000      10.000000    13.250000
# 25%      26.000000    57.00000      59.000000      57.750000    54.500000
# 50%      51.500000    66.00000      70.000000      69.000000    64.000000
# 75%      75.000000    77.00000      79.000000      79.000000    72.500000
# max      99.000000   100.00000     100.000000     100.000000    94.500000
#
#        english score       score1       score2
# count    1000.000000  1000.000000  1000.000000
# mean       50.643000    50.667000    50.667000
# std        29.665023    28.232059    28.232059
# min         1.000000     1.000000     1.000000
# 25%        23.000000    26.000000    26.000000
# ...

# %%
#Oprations are done in rows
df_exams['math score'] + df_exams['reading score'] + df_exams['writing score']
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %%
#Average of all the scores
df_exams['total score'] = round((df_exams['math score'] + df_exams['reading score'] + df_exams['writing score'] + df_exams['english score'])/4, 2)

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    73        group B           bachelor's degree      standard
# 1    female    57        group C                some college      standard
# 2    female    47        group B             master's degree      standard
# 3      male    34        group A          associate's degree  free/reduced
# 4      male    68        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    51        group E             master's degree      standard
# 996    male    42        group C                 high school  free/reduced
# 997  female    55        group C                 high school  free/reduced
# 998  female    93        group D                some college      standard
# 999  female    19        group D                some college  free/reduced
#
# ...

# %%
#Count value counting using value_count()
df_exams['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
#Normalize=True meaning it gives us ratio/percentage
df_exams['gender'].value_counts(normalize=True)
# Out:
# gender
# female    0.518
# male      0.482
# Name: proportion, dtype: float64

# %%
df_exams['parental level of education'].value_counts(normalize=True)
# Out:
# parental level of education
# some college          0.226
# associate's degree    0.222
# high school           0.196
# some high school      0.179
# bachelor's degree     0.118
# master's degree       0.059
# Name: proportion, dtype: float64

# %%
#Sort Columns Ascending By Default These are only a copy
df_exams.sort_values('math score')
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 59   female    74        group C            some high school  free/reduced
# 980  female    66        group B                 high school  free/reduced
# 17   female    11        group B            some high school  free/reduced
# 787  female    73        group B                some college      standard
# 145  female    96        group C                some college  free/reduced
# ..      ...   ...            ...                         ...           ...
# 623    male    90        group A                some college      standard
# 625    male    60        group D                some college      standard
# 962  female    51        group E          associate's degree      standard
# 458  female    18        group E           bachelor's degree      standard
# 916    male    70        group E           bachelor's degree      standard
#
# ...

# %%
#Sorting Columns by Decending
df_exams.sort_values('math score', ascending=False)
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 451  female    15        group E                some college      standard
# 458  female    18        group E           bachelor's degree      standard
# 962  female    51        group E          associate's degree      standard
# 149    male    85        group E          associate's degree  free/reduced
# 623    male    90        group A                some college      standard
# ..      ...   ...            ...                         ...           ...
# 145  female    96        group C                some college  free/reduced
# 787  female    73        group B                some college      standard
# 17   female    11        group B            some high school  free/reduced
# 980  female    66        group B                 high school  free/reduced
# 59   female    74        group C            some high school  free/reduced
#
# ...

# %%
#Sorting Columns by multiple columns 
df_exams.sort_values(['math score', 'reading score'], ascending=False)
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 149    male    85        group E          associate's degree  free/reduced
# 458  female    18        group E           bachelor's degree      standard
# 916    male    70        group E           bachelor's degree      standard
# 962  female    51        group E          associate's degree      standard
# 625    male    60        group D                some college      standard
# ..      ...   ...            ...                         ...           ...
# 145  female    96        group C                some college  free/reduced
# 787  female    73        group B                some college      standard
# 17   female    11        group B            some high school  free/reduced
# 980  female    66        group B                 high school  free/reduced
# 59   female    74        group C            some high school  free/reduced
#
# ...

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    73        group B           bachelor's degree      standard
# 1    female    57        group C                some college      standard
# 2    female    47        group B             master's degree      standard
# 3      male    34        group A          associate's degree  free/reduced
# 4      male    68        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    51        group E             master's degree      standard
# 996    male    42        group C                 high school  free/reduced
# 997  female    55        group C                 high school  free/reduced
# 998  female    93        group D                some college      standard
# 999  female    19        group D                some college  free/reduced
#
# ...

# %%
#Sorting Columns by multiple columns inplace meaning Updating orignal Dataframe
df_exams.sort_values(['math score', 'reading score'], ascending=False, inplace=True)

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 149    male    85        group E          associate's degree  free/reduced
# 458  female    18        group E           bachelor's degree      standard
# 916    male    70        group E           bachelor's degree      standard
# 962  female    51        group E          associate's degree      standard
# 625    male    60        group D                some college      standard
# ..      ...   ...            ...                         ...           ...
# 145  female    96        group C                some college  free/reduced
# 787  female    73        group B                some college      standard
# 17   female    11        group B            some high school  free/reduced
# 980  female    66        group B                 high school  free/reduced
# 59   female    74        group C            some high school  free/reduced
#
# ...

# %%
#Sorting Columns with key function
df_exams.sort_values('race/ethnicity', key=lambda col:col.str.lower())
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 741  female    98        group A          associate's degree  free/reduced
# 151    male    93        group A           bachelor's degree      standard
# 811    male    17        group A                 high school  free/reduced
# 112    male    23        group A          associate's degree      standard
# 25     male    76        group A             master's degree  free/reduced
# ..      ...   ...            ...                         ...           ...
# 751    male     4        group E                some college      standard
# 915  female    89        group E                some college      standard
# 592    male    91        group E           bachelor's degree      standard
# 479    male    85        group E          associate's degree      standard
# 517  female    70        group E                some college      standard
#
# ...

# %%
import random

# %%
#Create New Index
new_index = np.arange(0,1000)

# %%
#Shuffle Indexes
random.shuffle(new_index)

# %%
#Create new column with new index
df_exams['new_index'] = new_index

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 149    male    85        group E          associate's degree  free/reduced
# 458  female    18        group E           bachelor's degree      standard
# 916    male    70        group E           bachelor's degree      standard
# 962  female    51        group E          associate's degree      standard
# 625    male    60        group D                some college      standard
# ..      ...   ...            ...                         ...           ...
# 145  female    96        group C                some college  free/reduced
# 787  female    73        group B                some college      standard
# 17   female    11        group B            some high school  free/reduced
# 980  female    66        group B                 high school  free/reduced
# 59   female    74        group C            some high school  free/reduced
#
# ...

# %%
#Setting New index only a copy
df_exams.set_index('new_index')
# Out:
#            gender  test race/ethnicity parental level of education  \
# new_index
# 119          male    85        group E          associate's degree
# 500        female    18        group E           bachelor's degree
# 877          male    70        group E           bachelor's degree
# 10         female    51        group E          associate's degree
# 881          male    60        group D                some college
# ...           ...   ...            ...                         ...
# 792        female    96        group C                some college
# 683        female    73        group B                some college
# 793        female    11        group B            some high school
# 517        female    66        group B                 high school
# 989        female    74        group C            some high school
#
#                   lunch test preparation course  math score  reading score  \
# new_index
# ...

# %%
df_exams.set_index('new_index', inplace=True)

# %%
df_exams
# Out:
#            gender  test race/ethnicity parental level of education  \
# new_index
# 119          male    85        group E          associate's degree
# 500        female    18        group E           bachelor's degree
# 877          male    70        group E           bachelor's degree
# 10         female    51        group E          associate's degree
# 881          male    60        group D                some college
# ...           ...   ...            ...                         ...
# 792        female    96        group C                some college
# 683        female    73        group B                some college
# 793        female    11        group B            some high school
# 517        female    66        group B                 high school
# 989        female    74        group C            some high school
#
#                   lunch test preparation course  math score  reading score  \
# new_index
# ...

# %%
df_exams.sort_index()
# Out:
#            gender  test race/ethnicity parental level of education  \
# new_index
# 0          female    20        group E            some high school
# 1            male    10        group D             master's degree
# 2          female    73        group B           bachelor's degree
# 3          female    89        group B                 high school
# 4            male    76        group B                 high school
# ...           ...   ...            ...                         ...
# 995          male    48        group C                 high school
# 996        female    77        group D             master's degree
# 997          male    66        group D          associate's degree
# 998        female    73        group A             master's degree
# 999        female     5        group C                some college
#
#                   lunch test preparation course  math score  reading score  \
# new_index
# ...

# %%
#Rename Columns only a copy
df_exams.rename(columns={'gender':'Gender'})
# Out:
#            Gender  test race/ethnicity parental level of education  \
# new_index
# 119          male    85        group E          associate's degree
# 500        female    18        group E           bachelor's degree
# 877          male    70        group E           bachelor's degree
# 10         female    51        group E          associate's degree
# 881          male    60        group D                some college
# ...           ...   ...            ...                         ...
# 792        female    96        group C                some college
# 683        female    73        group B                some college
# 793        female    11        group B            some high school
# 517        female    66        group B                 high school
# 989        female    74        group C            some high school
#
#                   lunch test preparation course  math score  reading score  \
# new_index
# ...

# %%
df_exams
# Out:
#            gender  test race/ethnicity parental level of education  \
# new_index
# 119          male    85        group E          associate's degree
# 500        female    18        group E           bachelor's degree
# 877          male    70        group E           bachelor's degree
# 10         female    51        group E          associate's degree
# 881          male    60        group D                some college
# ...           ...   ...            ...                         ...
# 792        female    96        group C                some college
# 683        female    73        group B                some college
# 793        female    11        group B            some high school
# 517        female    66        group B                 high school
# 989        female    74        group C            some high school
#
#                   lunch test preparation course  math score  reading score  \
# new_index
# ...

# %%
#Updated the renamed
df_exams=df_exams.rename(columns={'gender':'Gender'})

# %%
df_exams
# Out:
#            Gender  test race/ethnicity parental level of education  \
# new_index
# 119          male    85        group E          associate's degree
# 500        female    18        group E           bachelor's degree
# 877          male    70        group E           bachelor's degree
# 10         female    51        group E          associate's degree
# 881          male    60        group D                some college
# ...           ...   ...            ...                         ...
# 792        female    96        group C                some college
# 683        female    73        group B                some college
# 793        female    11        group B            some high school
# 517        female    66        group B                 high school
# 989        female    74        group C            some high school
#
#                   lunch test preparation course  math score  reading score  \
# new_index
# ...

# %%
#Renameing Multiple columns
df_exams.rename(columns={'math score':'MS', 'reading score':'RS', 'writing score':'WS'}, inplace=True)

# %%
df_exams
# Out:
#            Gender  test race/ethnicity parental level of education  \
# new_index
# 119          male    85        group E          associate's degree
# 500        female    18        group E           bachelor's degree
# 877          male    70        group E           bachelor's degree
# 10         female    51        group E          associate's degree
# 881          male    60        group D                some college
# ...           ...   ...            ...                         ...
# 792        female    96        group C                some college
# 683        female    73        group B                some college
# 793        female    11        group B            some high school
# 517        female    66        group B                 high school
# 989        female    74        group C            some high school
#
#                   lunch test preparation course   MS   RS   WS  total score  \
# new_index
# ...

# %%
df_exams.sort_index(inplace=True)

# %%
df_exams
# Out:
#            Gender  test race/ethnicity parental level of education  \
# new_index
# 0          female    20        group E            some high school
# 1            male    10        group D             master's degree
# 2          female    73        group B           bachelor's degree
# 3          female    89        group B                 high school
# 4            male    76        group B                 high school
# ...           ...   ...            ...                         ...
# 995          male    48        group C                 high school
# 996        female    77        group D             master's degree
# 997          male    66        group D          associate's degree
# 998        female    73        group A             master's degree
# 999        female     5        group C                some college
#
#                   lunch test preparation course  MS  RS  WS  total score  \
# new_index
# ...

# %%
#Renameing Indexes
df_exams.rename(index={0:'A', 1:'B', 2:'C'}, inplace=True)

# %%
df_exams.head()
# Out:
#            Gender  test race/ethnicity parental level of education  \
# new_index
# A          female    20        group E            some high school
# B            male    10        group D             master's degree
# C          female    73        group B           bachelor's degree
# 3          female    89        group B                 high school
# 4            male    76        group B                 high school
#
#                   lunch test preparation course  MS  RS  WS  total score  \
# new_index
# A          free/reduced                    none  72  79  77        62.50
# B              standard                    none  82  82  74        72.00
# C              standard                    none  72  72  74        77.25
# 3              standard               completed  58  70  68        55.75
# 4              standard                    none  60  68  60        67.75
#
#            english score  score1  score2
# new_index
# A                     22      20      20
# ...
