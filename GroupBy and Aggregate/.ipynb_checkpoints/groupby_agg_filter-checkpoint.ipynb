# %%
import pandas as pd

# %%
df = pd.read_csv('Car_sales.csv')

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df=df[['Manufacturer', 'Sales_in_thousands', 'Vehicle_type',
       'Price_in_thousands', 'Engine_size', 'Horsepower', 'Fuel_capacity']]

# %%
df
# Out:
#     Manufacturer  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 0          Acura              16.919    Passenger               21.50
# 1          Acura              39.384    Passenger               28.40
# 2          Acura              14.114    Passenger                 NaN
# 3          Acura               8.588    Passenger               42.00
# 4           Audi              20.397    Passenger               23.99
# ..           ...                 ...          ...                 ...
# 152        Volvo               3.545    Passenger               24.40
# 153        Volvo              15.245    Passenger               27.50
# 154        Volvo              17.531    Passenger               28.80
# 155        Volvo               3.493    Passenger               45.50
# 156        Volvo              18.969    Passenger               36.00
#
#      Engine_size  Horsepower  Fuel_capacity
# 0            1.8       140.0           13.2
# ...

# %%
df.nunique()
# Out:
# Manufacturer           30
# Sales_in_thousands    157
# Vehicle_type            2
# Price_in_thousands    152
# Engine_size            31
# Horsepower             66
# Fuel_capacity          55
# dtype: int64

# %%
df.agg('sum')
# Out:
# Manufacturer          AcuraAcuraAcuraAcuraAudiAudiAudiBMWBMWBMWBuick...
# Sales_in_thousands                                             8320.698
# Vehicle_type          PassengerPassengerPassengerPassengerPassengerP...
# Price_in_thousands                                             4245.567
# Engine_size                                                       477.5
# Horsepower                                                      29008.0
# Fuel_capacity                                                    2800.5
# dtype: object

# %%
df.agg('mean',numeric_only=True)
# Out:
# Sales_in_thousands     52.998076
# Price_in_thousands     27.390755
# Engine_size             3.060897
# Horsepower            185.948718
# Fuel_capacity          17.951923
# dtype: float64

# %%
# here multiple aggregation methords are implemented by giving them in [''] form
df.select_dtypes(include='number').agg(['mean', 'count'])
# Out:
#        Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# mean            52.998076           27.390755     3.060897  185.948718
# count          157.000000          155.000000   156.000000  156.000000
#
#        Fuel_capacity
# mean       17.951923
# count     156.000000

# %%
# here we apply diffrent agg methords to diffrent columns for result it is declared as {"Key": ['val1', 'val2']}
df.agg({'Sales_in_thousands': ['sum', 'mean'],
        'Price_in_thousands': ['sum', 'max']
       })
# Out:
#       Sales_in_thousands  Price_in_thousands
# sum          8320.698000            4245.567
# mean           52.998076                 NaN
# max                  NaN              85.500

# %%
# operation done on two cols and resultant is print so sale + price of each row is given:
df[['Sales_in_thousands', 'Price_in_thousands']].agg('sum', axis=1)
# Out:
# 0      38.419
# 1      67.784
# 2      14.114
# 3      50.588
# 4      44.387
#         ...
# 152    27.945
# 153    42.745
# 154    46.331
# 155    48.993
# 156    54.969
# Length: 157, dtype: float64

# %%
df.agg(x=('Sales_in_thousands', 'sum'), y=('Price_in_thousands', 'sum'))
# Out:
#    Sales_in_thousands  Price_in_thousands
# x            8320.698                 NaN
# y                 NaN            4245.567

# %% [markdown]
# ### Split apply combine strategy for grouping

# %%
# Splitting through filtering
car=df['Vehicle_type']=='Car'
passenger=df['Vehicle_type']=='Passenger'

# %%
# apply by ging specific values for diffrent filters
car_a=df[car]['Sales_in_thousands'].agg('mean')
passenger_a=df[passenger]['Sales_in_thousands'].agg('mean')

# %%
# combine the result and form a new df
pd.DataFrame({'Vehicle_type': ['Car', 'Passanger'],
              'Sales_in_thousands': [car_a, passenger_a]
             })
# Out:
#   Vehicle_type  Sales_in_thousands
# 0          Car           80.622293
# 1    Passanger           43.234345

# %% [markdown]
# ### groupby() will be used to do the above done task in more siple way

# %%
df.groupby('Vehicle_type').agg('mean', numeric_only=True)
# Out:
#               Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# Vehicle_type
# Car                    80.622293           26.319975     3.520000  186.400000
# Passenger              43.234345           27.763200     2.902586  185.793103
#
#               Fuel_capacity
# Vehicle_type
# Car               21.895000
# Passenger         16.592241

# %%
gb=df.groupby('Manufacturer')

# %%
gb

# %%
gb.groups.keys()
# Out:
# dict_keys(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet', 'Chrysler', 'Dodge', 'Ford', 'Honda', 'Hyundai', 'Infiniti', 'Jaguar', 'Jeep', 'Lexus', 'Lincoln', 'Mercedes-B', 'Mercury', 'Mitsubishi', 'Nissan', 'Oldsmobile', 'Plymouth', 'Pontiac', 'Porsche', 'Saab', 'Saturn', 'Subaru', 'Toyota', 'Volkswagen', 'Volvo'])

# %%
gb.get_group('Toyota')
# Out:
#     Manufacturer  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 136       Toyota             142.535    Passenger              13.108
# 137       Toyota             247.994    Passenger              17.518
# 138       Toyota              63.849    Passenger              25.545
# 139       Toyota              33.269    Passenger              16.875
# 140       Toyota              84.087          Car              11.528
# 141       Toyota              65.119          Car              22.368
# 142       Toyota              25.106          Car              16.888
# 143       Toyota              68.411          Car              22.288
# 144       Toyota               9.835          Car              51.728
#
#      Engine_size  Horsepower  Fuel_capacity
# 136          1.8       120.0           13.2
# 137          2.2       133.0           18.5
# 138          3.0       210.0           18.5
# 139          1.8       140.0           14.5
# ...

# %%
df.groupby('Manufacturer').agg('mean', numeric_only=True)
# Out:
#               Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# Manufacturer
# Acura                  19.751250           30.633333     2.925000  200.000000
# Audi                   13.519000           39.980000     2.933333  220.000000
# BMW                    15.501667           33.096667     2.700000  185.333333
# Buick                  60.504750           26.781250     3.625000  206.250000
# Cadillac               22.435600           40.254000     4.500000  256.000000
# Chevrolet              61.596111           20.022778     3.055556  171.111111
# Chrysler               28.817286           23.430833     2.783333  194.833333
# Dodge                  82.740818           24.213636     3.709091  199.545455
# Ford                  183.875909           21.047273     3.327273  170.090909
# Honda                 118.534800           20.277000     2.520000  160.400000
# Hyundai                45.775333           12.165667     1.966667  126.666667
# ...

# %%
df.groupby('Manufacturer').agg('sum', numeric_only=True)
# Out:
#               Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# Manufacturer
# Acura                     79.005              91.900         11.7       800.0
# Audi                      40.557             119.940          8.8       660.0
# BMW                       46.505              99.290          8.1       556.0
# Buick                    242.019             107.125         14.5       825.0
# Cadillac                 112.178             201.270         22.5      1280.0
# Chevrolet                554.365             180.205         27.5      1540.0
# Chrysler                 201.721             140.585         16.7      1169.0
# Dodge                    910.149             266.350         40.8      2195.0
# Ford                    2022.635             231.520         36.6      1871.0
# Honda                    592.674             101.385         12.6       802.0
# Hyundai                  137.326              36.497          5.9       380.0
# ...

# %%
df.groupby('Vehicle_type').count()
# Out:
#               Manufacturer  Sales_in_thousands  Price_in_thousands  \
# Vehicle_type
# Car                     41                  41                  40
# Passenger              116                 116                 115
#
#               Engine_size  Horsepower  Fuel_capacity
# Vehicle_type
# Car                    40          40             40
# Passenger             116         116            116

# %%
df.isnull().sum()
# Out:
# Manufacturer          0
# Sales_in_thousands    0
# Vehicle_type          0
# Price_in_thousands    2
# Engine_size           1
# Horsepower            1
# Fuel_capacity         1
# dtype: int64

# %%
df.groupby('Engine_size', dropna=False).count()
# Out:
#              Manufacturer  Sales_in_thousands  Vehicle_type  \
# Engine_size
# 1.0                     1                   1             1
# 1.5                     1                   1             1
# 1.6                     1                   1             1
# 1.8                     8                   8             8
# 1.9                     5                   5             5
# 2.0                    17                  17            17
# 2.2                     4                   4             4
# 2.3                     6                   6             6
# 2.4                    11                  11            11
# 2.5                    11                  11            11
# 2.7                     4                   4             4
# 2.8                     3                   3             3
# 2.9                     1                   1             1
# 3.0                    14                  14            14
# ...

# %% [markdown]
# ### groupby aand agg methords for complex operations

# %%
df.groupby('Manufacturer').agg(['min', 'max'])
# Out:
#              Sales_in_thousands          Vehicle_type             \
#                             min      max          min        max
# Manufacturer
# Acura                     8.588   39.384    Passenger  Passenger
# Audi                      1.380   20.397    Passenger  Passenger
# BMW                       9.231   19.747    Passenger  Passenger
# Buick                    27.851   91.561    Passenger  Passenger
# Cadillac                  6.536   63.729          Car  Passenger
# Chevrolet                17.947  145.519    Passenger  Passenger
# Chrysler                  7.854   53.480          Car  Passenger
# Dodge                     0.916  227.061          Car  Passenger
# Ford                     35.068  540.561          Car  Passenger
# Honda                    12.855  230.902          Car  Passenger
# Hyundai                  29.450   66.692    Passenger  Passenger
# Infiniti                 23.713   23.713    Passenger  Passenger
# ...

# %%
df.groupby('Vehicle_type').agg( Min_engine=('Engine_size', 'min'), max_horses=('Horsepower', 'max'))
# Out:
#               Min_engine  max_horses
# Vehicle_type
# Car                  2.0       300.0
# Passenger            1.0       450.0

# %%
df.groupby('Manufacturer').agg(total_sales=('Sales_in_thousands', 'sum'), average_price=('Price_in_thousands','mean'))
# Out:
#               total_sales  average_price
# Manufacturer
# Acura              79.005      30.633333
# Audi               40.557      39.980000
# BMW                46.505      33.096667
# Buick             242.019      26.781250
# Cadillac          112.178      40.254000
# Chevrolet         554.365      20.022778
# Chrysler          201.721      23.430833
# Dodge             910.149      24.213636
# Ford             2022.635      21.047273
# Honda             592.674      20.277000
# Hyundai           137.326      12.165667
# Infiniti           23.713      29.465000
# Jaguar             15.467      42.800000
# Jeep              293.153      20.991667
# Lexus             106.843      44.055000
# Lincoln            85.634      41.690000
# Mercedes-B        117.125      52.916667
# Mercury           237.999      20.748333
# Mitsubishi        180.895      22.167429
# Nissan            399.635      22.360714
# Oldsmobile        178.989      25.622833
# ...

# %%
df
# Out:
#     Manufacturer  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 0          Acura              16.919    Passenger               21.50
# 1          Acura              39.384    Passenger               28.40
# 2          Acura              14.114    Passenger                 NaN
# 3          Acura               8.588    Passenger               42.00
# 4           Audi              20.397    Passenger               23.99
# ..           ...                 ...          ...                 ...
# 152        Volvo               3.545    Passenger               24.40
# 153        Volvo              15.245    Passenger               27.50
# 154        Volvo              17.531    Passenger               28.80
# 155        Volvo               3.493    Passenger               45.50
# 156        Volvo              18.969    Passenger               36.00
#
#      Engine_size  Horsepower  Fuel_capacity
# 0            1.8       140.0           13.2
# ...

# %% [markdown]
# ### lambga func with groupby

# %%
bars=df.groupby('Manufacturer').agg('sum',
                               numeric_only=True).apply(lambda x:x*1000)[['Sales_in_thousands', 
                                                                                 'Price_in_thousands']].sort_values('Sales_in_thousands', ascending=False)

# %%
import plotly.express as px

# %%
px.bar(bars, barmode='group')

# %%
# filter function is to be made and then passed to .filter methord so that it can be used for filtering 
def fltr(x):
    return x['Sales_in_thousands'].sum()>52

# %%
df_f=df.groupby('Manufacturer').filter(fltr)

# %%
print(df.shape)
print(df_f.shape)
# Out:
# (157, 7)
# (144, 7)
