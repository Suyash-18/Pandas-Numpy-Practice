# %%
import pandas as pd

# %%
df_m=pd.read_csv('IMDb movies.csv', low_memory=False)
df_r=pd.read_csv('IMDb ratings.csv', low_memory=True)

# %%
df_m.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
# ...

# %%
df_m.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
df_m= df_m[['imdb_title_id', 'title', 'year', 'genre', 'country', ]]
df_r=df_r[['imdb_title_id', 'total_votes', 'mean_vote']]

# %%
df_m.head()
# Out:
#   imdb_title_id                        title  year                      genre  \
# 0     tt0000009                   Miss Jerry  1894                    Romance
# 1     tt0000574  The Story of the Kelly Gang  1906    Biography, Crime, Drama
# 2     tt0001892               Den sorte drøm  1911                      Drama
# 3     tt0002101                    Cleopatra  1912             Drama, History
# 4     tt0002130                    L'Inferno  1911  Adventure, Drama, Fantasy
#
#             country
# 0               USA
# 1         Australia
# 2  Germany, Denmark
# 3               USA
# 4             Italy

# %%
df_r.columns
# Out:
# Index(['imdb_title_id', 'total_votes', 'mean_vote'], dtype='object')

# %%
df1=pd.DataFrame({'id': ['A', 'B','C','D'],
                 'age': [18,20,21,20]},)
df2=pd.DataFrame({'id': ['E', 'F','G','H'],
                 'age': [19,22,23,17]})

# %%
df1
# Out:
#   id  age
# 0  A   18
# 1  B   20
# 2  C   21
# 3  D   20

# %%
df2
# Out:
#   id  age
# 0  E   19
# 1  F   22
# 2  G   23
# 3  H   17

# %%
pd.concat([df1,df2],ignore_index=True)
# Out:
#   id  age
# 0  A   18
# 1  B   20
# 2  C   21
# 3  D   20
# 4  E   19
# 5  F   22
# 6  G   23
# 7  H   17

# %%
df_ms=df_m.sample(frac=0.5)

# %%
df_ms.shape
# Out:
# (42928, 5)

# %%
pd.concat([df_m,df_ms])
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 83981     tt8246392                           Furie  2019
# 32668     tt0139877                        La balia  1999
# 59956     tt1607583             Shut Up and Kiss Me  2010
# 75863     tt4827986          The Sense of an Ending  2017
# 25058     tt0098732  Últimas imágenes del naufragio  1989
#
#                            genre           country
# 0                        Romance               USA
# 1        Biography, Crime, Drama         Australia
# 2                          Drama  Germany, Denmark
# 3                 Drama, History               USA
# ...

# %%
print(df_m.shape)
print(df_r.shape)
# Out:
# (85855, 5)
# (85855, 3)

# %%
df_m.set_index('imdb_title_id',inplace=True)
df_r.set_index('imdb_title_id',inplace=True)

# %%
con=pd.concat([df_m, df_r], axis=1)

# %%
con.shape
# Out:
# (85855, 6)

# %%
con
# Out:
#                                         title  year  \
# imdb_title_id
# tt0000009                          Miss Jerry  1894
# tt0000574         The Story of the Kelly Gang  1906
# tt0001892                      Den sorte drøm  1911
# tt0002101                           Cleopatra  1912
# tt0002130                           L'Inferno  1911
# ...                                       ...   ...
# tt9908390                             Le lion  2020
# tt9911196      De Beentjes van Sint-Hildegard  2020
# tt9911774           Padmavyuhathile Abhimanyu  2019
# tt9914286                   Sokagin Çocuklari  2019
# tt9914942          La vida sense la Sara Amat  2019
#
#                                    genre           country  total_votes  \
# imdb_title_id
# tt0000009                        Romance               USA          154
# tt0000574        Biography, Crime, Drama         Australia          589
# tt0001892                          Drama  Germany, Denmark          188
# ...
